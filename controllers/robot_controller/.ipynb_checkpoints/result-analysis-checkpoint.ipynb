# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Baca data dari file CSV
file_path1 = 'output_fixed.csv'  # Ganti dengan path ke file CSV Anda
file_path2 = 'output_pid.csv'
file_path3 = 'output_fuzzy.csv'

data_fixed = pd.read_csv(file_path1)
data_pid = pd.read_csv(file_path2)
data_fuzzy = pd.read_csv(file_path2)

# %%
# Baca data dari file CSV
file_path1_arena2 = 'output_fixed_arena2.csv'  # Ganti dengan path ke file CSV Anda
file_path2_arena2 = 'output_pid_arena2.csv'
file_path3_arena2 = 'output_fuzzy_arena2.csv'

data_fixed_arena2 = pd.read_csv(file_path1_arena2)
data_pid_arena2 = pd.read_csv(file_path2_arena2)
data_fuzzy_arena2 = pd.read_csv(file_path2_arena2)

# %% [markdown]
# # Visualisasi Perjalanan Robot

# %%
# Plot posisi X dan Y
plt.figure(figsize=(10, 6))
plt.plot(data_fixed['X'], data_fixed['Y'], linestyle='dashed', color='r', linewidth=3)
plt.plot(data_pid['X'], data_pid['Y'], linestyle='dashdot', color='g', linewidth=3)
plt.plot(data_fuzzy['X'], data_fuzzy['Y'], linestyle='dotted', color='b', linewidth=3)
plt.title('Tracking Perjalanan Robot')
plt.xlabel('Posisi X')
plt.ylabel('Posisi Y')
plt.legend(['Fixed Base Speed', 'PID Base Speed', 'Fuzzy Base Speed']) 
plt.grid(True)
plt.axis('equal')  # Membuat skala pada sumbu X dan Y sama besarnya
plt.show()

# %%
# Plot posisi X dan Y
plt.figure(figsize=(10, 6))
plt.plot(data_fixed_arena2['X'], data_fixed_arena2['Y'], linestyle='dashed', color='r', linewidth=3)
plt.plot(data_pid_arena2['X'], data_pid_arena2['Y'], linestyle='dashdot', color='g', linewidth=3)
plt.plot(data_fuzzy_arena2['X'], data_fuzzy_arena2['Y'], linestyle='dotted', color='b', linewidth=3)
plt.title('Tracking Perjalanan Robot')
plt.xlabel('Posisi X')
plt.ylabel('Posisi Y')
plt.legend(['Fixed Base Speed', 'PID Base Speed', 'Fuzzy Base Speed']) 
plt.grid(True)
plt.axis('equal')  # Membuat skala pada sumbu X dan Y sama besarnya
plt.show()

# %% [markdown]
# # Analisis Kinerja PID Controller

# %%
# Plot Error dan DeltaError terhadap waktu
plt.figure(figsize=(10, 6))
plt.plot(data_fixed['Time'], data_fixed['Error'], label='Error Fixed', linewidth=1, alpha=0.7)
plt.plot(data_pid['Time'], data_pid['Error'], label='Error PID', linewidth=2, alpha=0.7)
plt.plot(data_fuzzy['Time'], data_fuzzy['Error'], label='Error Fuzzy', linewidth=1, alpha=0.7)
#plt.plot(data['Time'], data['IntegralError'], label='IntegralError', color='g', linewidth=1)
#plt.plot(data['Time'], data['DeltaError'], label='DeltaError', color='b', linewidth=1)
#plt.title('Error, IntegralError dan DeltaError terhadap Waktu')
plt.title('Error terhadap Waktu')
plt.xlabel('Waktu (s)')
plt.ylabel('Nilai Error')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot DeltaSpeed terhadap waktu
plt.figure(figsize=(10, 6))
plt.plot(data['Time'], data['DeltaSpeed'], label='DeltaSpeed', color='b', linewidth=1)
plt.title('DeltaSpeed terhadap Waktu')
plt.xlabel('Waktu (s)')
plt.ylabel('DeltaSpeed')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Mean Absolute Error (MAE)

# %%
mae = data['Error'].abs().mean()
print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# Mean Absolute Error (MAE): 3.7305785123966944

# %% [markdown]
# ## Mean Squared Error (MSE)

# %%
mse = (data['Error'] ** 2).mean()
print(f'Mean Squared Error (MSE): {mse}')
# Out:
# Mean Squared Error (MSE): 44.3267217630854

# %% [markdown]
# ## Root Mean Squared Error (RMSE)

# %%
rmse = mse ** 0.5
print(f'Root Mean Squared Error (RMSE): {rmse}')
# Out:
# Root Mean Squared Error (RMSE): 6.657831611199355

# %% [markdown]
# ## Mean Absolute Percentage Error (MAPE)

# %%
mape = (data['Error'].abs() / data['SetPointError']).mean() * 100
print(f'Mean Absolute Percentage Error (MAPE): {mape:.2f}%')
# Out:
# Mean Absolute Percentage Error (MAPE): 2.33%

# %%
# Hitung metrik error
mae = data['Error'].abs().mean()
mse = (data['Error'] ** 2).mean()
rmse = mse ** 0.5
mape = (data['Error'].abs() / data['SetPointError']).mean() * 100

# Cetak hasil
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Percentage Error (MAPE): {mape:.2f}%')
# Out:
# Mean Absolute Error (MAE): 3.7305785123966944
# Mean Squared Error (MSE): 44.3267217630854
# Root Mean Squared Error (RMSE): 6.657831611199355
# Mean Absolute Percentage Error (MAPE): 2.33%

# %% [markdown]
# # Analisis respon transien

# %%
# Plot respons Error terhadap waktu
plt.figure(figsize=(10, 6))
plt.plot(data['Time'], data['Error'], label='Error', color='r')
plt.title('Error terhadap Waktu')
plt.xlabel('Waktu (s)')
plt.ylabel('Error')
plt.grid(True)
plt.legend()
plt.show()

# Analisis respons transien
def analyze_transient_response(time, error, set_point):
    error_abs = error.abs()
    
    rise_time_idx = (error_abs > 0.1 * set_point).idxmax()
    rise_time = time[rise_time_idx]

    peak_error = error.max()
    peak_time_idx = error.idxmax()
    peak_time = time[peak_time_idx]

    overshoot = ((peak_error - set_point) / set_point) * 100

    settling_time_idx = (error_abs <= 0.02 * set_point).idxmax()
    settling_time = time[settling_time_idx]

    return rise_time, peak_time, overshoot, settling_time

set_point = data['SetPointError'].iloc[0]  # Misalkan set point konstan
time = data['Time']
error = data['Error']

rise_time, peak_time, overshoot, settling_time = analyze_transient_response(time, error, set_point)

print(f'Rise Time: {rise_time} s')
print(f'Peak Time: {peak_time} s')
print(f'Overshoot: {overshoot:.2f} %')
print(f'Settling Time: {settling_time} s')
# Out:
# Rise Time: 8.544 s
# Peak Time: 46.848 s
# Overshoot: -78.12 %
# Settling Time: 0.064 s

# %% [markdown]
# # Analisis Kecepatan Roda

# %%
# Plot kecepatan roda kiri dan kanan terhadap waktu
plt.figure(figsize=(10, 6))
plt.plot(data['Time'], data['LeftSpeed'], label='LeftSpeed', color='c', linewidth=0.5)
plt.plot(data['Time'], data['RightSpeed'], label='RightSpeed', color='m')
plt.title('Kecepatan Roda terhadap Waktu')
plt.xlabel('Waktu (s)')
plt.ylabel('Kecepatan')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Analisis Orientasi Robot

# %%
# Plot Roll, Pitch, dan Yaw terhadap waktu
plt.figure(figsize=(10, 6))
plt.plot(data['Time'], data['Roll'], label='Roll', color='r', linewidth=0.5)
plt.plot(data['Time'], data['Pitch'], label='Pitch', color='g', linewidth=0.5)
plt.plot(data['Time'], data['Yaw'], label='Yaw', color='b', linewidth=0.5)
plt.title('Orientasi Robot terhadap Waktu')
plt.xlabel('Waktu (s)')
plt.ylabel('Orientasi (derajat)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Analisis Korelasi

# %%
import seaborn as sns

# Hitung matriks korelasi
correlation_matrix = data.corr()

# Plot heatmap dari matriks korelasi
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Heatmap Korelasi Antar Parameter')
plt.show()

# %% [markdown]
# # Analisis Stabilitas

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['Time'], data['SetPointError'], label='SetPointError', color='b')
plt.plot(data['Time'], data['Error'], label='Error', color='r')
plt.title('SetPoint vs Error terhadap Waktu')
plt.xlabel('Waktu (s)')
plt.ylabel('Nilai')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Analisis Kinerja Dinamis

# %%
# Plot DeltaSpeed terhadap waktu
plt.figure(figsize=(10, 6))
plt.plot(data_fixed['Time'], data_fixed['DeltaSpeed'], label='Fixed Base Speed', color='r')
plt.plot(data_pid['Time'], data_pid['DeltaSpeed'], label='PID Base Speed', color='g')
plt.plot(data_fuzzy['Time'], data_fuzzy['DeltaSpeed'], label='Fuzzy Base Speed', color='b')
plt.title('DeltaSpeed terhadap Waktu')
plt.xlabel('Waktu (s)')
plt.ylabel('DeltaSpeed')
plt.legend(['Fixed Base Speed', 'PID Base Speed', 'Fuzzy Base Speed']) 
plt.grid(True)
plt.show()

# %%
# Plot BaseSpeed, LeftSpeed, dan RightSpeed terhadap waktu
plt.figure(figsize=(10, 6))
plt.plot(data['Time'], data['BaseSpeed'], label='BaseSpeed', color='k')
plt.plot(data['Time'], data['LeftSpeed'], label='LeftSpeed', color='c')
plt.plot(data['Time'], data['RightSpeed'], label='RightSpeed', color='m')
plt.title('Kecepatan terhadap Waktu')
plt.xlabel('Waktu (s)')
plt.ylabel('Kecepatan')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Analisis Konsistensi Kontrol

# %%
# Plot BaseSpeed dan DeltaSpeed terhadap waktu
plt.figure(figsize=(10, 6))
plt.plot(data_fixed['Time'], data_fixed['BaseSpeed'], label='Dynamic Base Speed', color='r')
plt.plot(data_fixed['Time'], data_fixed['DeltaSpeed'], label='PID Delta Speed', color='r')
plt.plot(data_pid['Time'], data_pid['BaseSpeed'], label='PID Base Speed', color='g')
plt.plot(data_pid['Time'], data_pid['DeltaSpeed'], label='PID Delta Speed', color='g')
plt.plot(data_fuzzy['Time'], data_fuzzy['BaseSpeed'], label='Fuzzy Base Speed', color='g')
plt.plot(data_fuzzy['Time'], data_fuzzy['DeltaSpeed'], label='Fuzzy Delta Speed', color='g')
plt.title('BaseSpeed dan DeltaSpeed terhadap Waktu')
plt.xlabel('Waktu (s)')
plt.ylabel('Kecepatan')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot DeltaSpeed terhadap waktu
plt.figure(figsize=(10, 6))
plt.plot(data_fixed_arena2['Time'], data_fixed_arena2['BaseSpeed'], label='Fixed Base Speed', color='g')
plt.plot(data_pid_arena2['Time'], data_pid_arena2['BaseSpeed'], label='PID Base Speed', color='r', alpha=0.5)
plt.plot(data_fuzzy_arena2['Time'], data_fuzzy_arena2['BaseSpeed'], label='Fuzzy Base Speed', color='b', alpha=0.5)
plt.title('DeltaSpeed terhadap Waktu')
plt.xlabel('Waktu (s)')
plt.ylabel('DeltaSpeed')
plt.legend(['Fixed Base Speed', 'PID Base Speed', 'Fuzzy Base Speed']) 
plt.grid(True)
plt.show()

# %%
# Plot Angle terhadap waktu
plt.figure(figsize=(10, 6))
plt.plot(data['Time'], data['Angle'], label='Angle', color='g')
plt.title('Angle terhadap Waktu')
plt.xlabel('Waktu (s)')
plt.ylabel('Angle (derajat)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Analisis Distribusi Error

# %%
plt.figure(figsize=(10, 6))
plt.hist(data_fixed_arena2['Error'], bins=50, color='r', alpha=0.5, label='Dynamic Base Speed')
plt.hist(data_pid_arena2['Error'], bins=50, color='g', alpha=0.5, label='PID Base Speed')
plt.hist(data_fuzzy_arena2['Error'], bins=50, color='b', alpha=0.5, label='PID Base Speed')
plt.title('Distribusi Error')
plt.xlabel('Error')
plt.ylabel('Frekuensi')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data2['Error'], bins=50, color='r', alpha=0.7)
plt.title('Distribusi Error')
plt.xlabel('Error')
plt.ylabel('Frekuensi')
plt.grid(True)
plt.show()
